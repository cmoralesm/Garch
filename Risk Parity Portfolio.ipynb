# %%
import numpy as np
import pandas as pd
import yfinance as yf

yf.pdr_override()
pd.options.display.float_format = '{:.4%}'.format

# Date range
start = '2020-01-01'
end = '2022-05-22'

# Tickers of assets
assets = ["SSO", "UBT", "UST", "UPW", "UGL"]
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
# [*********************100%***********************]  5 of 5 completed
#                 SSO      UBT      UGL      UPW      UST
# Date
# 2020-01-02  1.7966%  2.6009%  1.3252% -2.6778%  0.6739%
# 2020-01-03 -1.4849%  2.9488%  2.7163%  0.2663%  1.3548%
# 2020-01-06  0.7536% -1.0553%  2.0960%  0.2655% -0.2831%
# 2020-01-07 -0.5839% -1.0259%  0.7291% -0.4267% -0.2208%
# 2020-01-08  1.0164% -1.2315% -1.5048%  0.0295% -0.3319%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
b = None # Risk contribution constraints vector
w_rp = port.rp_optimization(model=model, rm=rm, rf=rf, b=b, hist=hist)

display(w_rp.T)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\super\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
#              SSO      UBT      UGL      UPW      UST
# weights 13.3314% 17.0736% 14.9140% 11.2205% 43.4605%

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w_rp,
                 title='Risk Parity Variance',
                 others=0.05,
                 nrow=25,
                 cmap = "tab20",
                 height=6,
                 width=10,
                 ax=None)
# Out:
# C:\Users\super\anaconda3\lib\site-packages\riskfolio\PlotFunctions.py:567: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   sizes2 = sizes2.append(item)

# %%
# Plotting the risk contribution per asset

mu = Y.mean()
cov = Y.cov() # Covariance matrix
returns = Y # Returns of the assets

ax = rp.plot_risk_con(w=w_rp,
                      cov=cov,
                      returns=returns,
                      rm=rm,
                      rf=0,
                      alpha=0.05,
                      color="tab:blue",
                      height=6,
                      width=10,
                      t_factor=252,
                      ax=None)

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.rp_optimization(model=model, rm=i, rf=rf, b=b, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# C:\Users\super\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# C:\Users\super\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# C:\Users\super\anaconda3\lib\site-packages\cvxpy\problems\problem.py:1337: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# <style type="text/css">
# #T_cf447_row0_col0 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_cf447_row0_col1, #T_cf447_row2_col0 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_cf447_row0_col2 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_cf447_row0_col3 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_cf447_row0_col4 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_cf447_row0_col5, #T_cf447_row0_col9, #T_cf447_row3_col6 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_cf447_row0_col6, #T_cf447_row1_col7, #T_cf447_row1_col8, #T_cf447_row3_col0, #T_cf447_row3_col1, #T_cf447_row3_col2, #T_cf447_row3_col3, #T_cf447_row3_col4, #T_cf447_row3_col5, #T_cf447_row3_col9 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_cf447_row0_col7 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_cf447_row0_col8, #T_cf447_row3_col8 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_cf447_row1_col0 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_cf447_row1_col1, #T_cf447_row2_col6 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_cf447_row1_col2 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_cf447_row1_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_cf447_row1_col4 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_cf447_row1_col5 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_cf447_row1_col6 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_cf447_row1_col9 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_cf447_row2_col1, #T_cf447_row2_col3 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_cf447_row2_col2 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_cf447_row2_col4 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_cf447_row2_col5 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_cf447_row2_col7, #T_cf447_row2_col8, #T_cf447_row4_col0, #T_cf447_row4_col1, #T_cf447_row4_col2, #T_cf447_row4_col3, #T_cf447_row4_col4, #T_cf447_row4_col5, #T_cf447_row4_col6, #T_cf447_row4_col9 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_cf447_row2_col9 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_cf447_row3_col7 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_cf447_row4_col7 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_cf447_row4_col8 {
#   background-color: #004629;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cf447">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf447_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_cf447_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_cf447_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_cf447_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_cf447_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_cf447_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_cf447_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_cf447_level0_col7" class="col_heading level0 col7" >CDaR</th>
#       <th id="T_cf447_level0_col8" class="col_heading level0 col8" >UCI</th>
#       <th id="T_cf447_level0_col9" class="col_heading level0 col9" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf447_level0_row0" class="row_heading level0 row0" >SSO</th>
#       <td id="T_cf447_row0_col0" class="data row0 col0" >13.33%</td>
#       <td id="T_cf447_row0_col1" class="data row0 col1" >15.51%</td>
#       <td id="T_cf447_row0_col2" class="data row0 col2" >12.97%</td>
#       <td id="T_cf447_row0_col3" class="data row0 col3" >14.67%</td>
#       <td id="T_cf447_row0_col4" class="data row0 col4" >13.08%</td>
#       <td id="T_cf447_row0_col5" class="data row0 col5" >12.54%</td>
#       <td id="T_cf447_row0_col6" class="data row0 col6" >8.47%</td>
#       <td id="T_cf447_row0_col7" class="data row0 col7" >14.76%</td>
#       <td id="T_cf447_row0_col8" class="data row0 col8" >19.38%</td>
#       <td id="T_cf447_row0_col9" class="data row0 col9" >13.65%</td>
#     </tr>
#     <tr>
#       <th id="T_cf447_level0_row1" class="row_heading level0 row1" >UBT</th>
#       <td id="T_cf447_row1_col0" class="data row1 col0" >17.07%</td>
#       <td id="T_cf447_row1_col1" class="data row1 col1" >17.12%</td>
#       <td id="T_cf447_row1_col2" class="data row1 col2" >17.15%</td>
#       <td id="T_cf447_row1_col3" class="data row1 col3" >17.12%</td>
#       <td id="T_cf447_row1_col4" class="data row1 col4" >16.95%</td>
#       <td id="T_cf447_row1_col5" class="data row1 col5" >17.14%</td>
#       <td id="T_cf447_row1_col6" class="data row1 col6" >17.60%</td>
#       <td id="T_cf447_row1_col7" class="data row1 col7" >11.07%</td>
#       <td id="T_cf447_row1_col8" class="data row1 col8" >11.01%</td>
#       <td id="T_cf447_row1_col9" class="data row1 col9" >14.17%</td>
#     </tr>
#     <tr>
#       <th id="T_cf447_level0_row2" class="row_heading level0 row2" >UGL</th>
#       <td id="T_cf447_row2_col0" class="data row2 col0" >14.91%</td>
#       <td id="T_cf447_row2_col1" class="data row2 col1" >16.36%</td>
#       <td id="T_cf447_row2_col2" class="data row2 col2" >15.87%</td>
#       <td id="T_cf447_row2_col3" class="data row2 col3" >15.93%</td>
#       <td id="T_cf447_row2_col4" class="data row2 col4" >16.04%</td>
#       <td id="T_cf447_row2_col5" class="data row2 col5" >15.09%</td>
#       <td id="T_cf447_row2_col6" class="data row2 col6" >15.75%</td>
#       <td id="T_cf447_row2_col7" class="data row2 col7" >28.90%</td>
#       <td id="T_cf447_row2_col8" class="data row2 col8" >25.15%</td>
#       <td id="T_cf447_row2_col9" class="data row2 col9" >24.00%</td>
#     </tr>
#     <tr>
#       <th id="T_cf447_level0_row3" class="row_heading level0 row3" >UPW</th>
#       <td id="T_cf447_row3_col0" class="data row3 col0" >11.22%</td>
#       <td id="T_cf447_row3_col1" class="data row3 col1" >12.47%</td>
#       <td id="T_cf447_row3_col2" class="data row3 col2" >11.99%</td>
#       <td id="T_cf447_row3_col3" class="data row3 col3" >11.58%</td>
#       <td id="T_cf447_row3_col4" class="data row3 col4" >11.98%</td>
#       <td id="T_cf447_row3_col5" class="data row3 col5" >12.39%</td>
#       <td id="T_cf447_row3_col6" class="data row3 col6" >8.66%</td>
#       <td id="T_cf447_row3_col7" class="data row3 col7" >19.65%</td>
#       <td id="T_cf447_row3_col8" class="data row3 col8" >19.39%</td>
#       <td id="T_cf447_row3_col9" class="data row3 col9" >13.56%</td>
#     </tr>
#     <tr>
#       <th id="T_cf447_level0_row4" class="row_heading level0 row4" >UST</th>
#       <td id="T_cf447_row4_col0" class="data row4 col0" >43.46%</td>
#       <td id="T_cf447_row4_col1" class="data row4 col1" >38.54%</td>
#       <td id="T_cf447_row4_col2" class="data row4 col2" >42.02%</td>
#       <td id="T_cf447_row4_col3" class="data row4 col3" >40.70%</td>
#       <td id="T_cf447_row4_col4" class="data row4 col4" >41.95%</td>
#       <td id="T_cf447_row4_col5" class="data row4 col5" >42.85%</td>
#       <td id="T_cf447_row4_col6" class="data row4 col6" >49.51%</td>
#       <td id="T_cf447_row4_col7" class="data row4 col7" >25.62%</td>
#       <td id="T_cf447_row4_col8" class="data row4 col8" >25.08%</td>
#       <td id="T_cf447_row4_col9" class="data row4 col9" >34.62%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(16)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <AxesSubplot:>
